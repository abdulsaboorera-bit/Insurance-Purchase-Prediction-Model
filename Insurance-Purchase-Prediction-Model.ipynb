# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulsaboorera-bit/Insurance-Purchase-Prediction-Model/blob/main/Insurance-Purchase-Prediction-Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('/content/insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='green')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 22   40
# 26   23
# 11   28
# 2    47
# 24   50
# 0    22

# %%
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.50883921, 0.49116079],
#        [0.88437386, 0.11562614],
#        [0.80946388, 0.19053612],
#        [0.31263654, 0.68736346],
#        [0.24220758, 0.75779242],
#        [0.89586628, 0.10413372]])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([0, 0, 0, 1, 1, 0])

# %%
X_test
# Out:
#     age
# 22   40
# 26   23
# 11   28
# 2    47
# 24   50
# 0    22

# %%
model.coef_
# Out:
# array([[0.11759749]])

# %%
model.intercept_
# Out:
# array([-4.73926008])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705
